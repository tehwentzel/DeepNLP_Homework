# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import copy
from multiprocessing.pool import Pool
import re
positive_file = 'data/rt-polarity.pos'
negative_file = 'data/rt-polarity.neg'
data_root = 'data/stanfordSentimentTreebank/'
glove_pattern = 'data/glove.6B.<size>d.txt'
glove_size = 300

# %%
glove_dict = None
def get_glove(size = 50):
    global glove_dict
    if glove_dict is None or len(list(glove_dict.values())[0]) != size:
        file = re.sub('<size>', str(size), glove_pattern)
        glove = pd.read_csv(file, sep = " ", header = None, index_col = 0, quoting = 3)
        glove_dict = {key: val.values for key, val in glove.T.items()}
    return glove_dict

def preprocess_sentence(line):
    line = re.sub(r'[^\x00-\x7F]+', '', line.strip())
    return line.strip().lower()

def preprocess_for_labels(line):
    line = preprocess_sentence(line)
    line = re.sub('\W+', '', line.strip())
    return line
    
def get_labelset(file):
    with open(file, "rt", encoding="utf-8") as f:
        sentences = set([preprocess_for_labels(line) for line in f.readlines()])
    return sentences

# %%
positive_labelset = get_labelset(positive_file)
negative_labelset = get_labelset(negative_file)

# %%
data_split_dict = {}
data_split_map = {'1': 'train', '2': 'test', '3':'val'}
with open(data_root + 'datasetSplit.txt', 'r') as f:
    for line in f.readlines():
        [index, set_code] = line.strip().split(',')
        try:
            index = int(index)
        except:
            continue
        if set_code not in data_split_map:
            print(index, set_code)
        data_split_dict[index] = data_split_map.get(set_code, 'val')

# %%
def check_sentiment(sentence):
    s = preprocess_for_labels(sentence)
    for y, labelset in enumerate([negative_labelset, positive_labelset]):
        for entry in labelset:
            if s in labelset:
                return y
    return -1

sentences = {}
word2ind = {}
ttws = tf.keras.preprocessing.text.text_to_word_sequence
n_skipped = 0
idx = 0
with open(data_root + 'datasetSentences.txt') as data:
    lines = data.readlines()
    for line in lines:
        index = re.search('^\d+', line)
        if index is None:
            continue
        index = int(index.group())
        if index not in data_split_dict:
            print(index, line)
        entry = {'split_set': data_split_dict.get(index, 'val')}
        line = preprocess_sentence(line)
        line = re.sub(r'^\d+\s+', '', line)
        sentiment = check_sentiment(line)
        if sentiment >= 0:
            entry['y'] = sentiment
        else:
            n_skipped += 1
            continue
        sentences[line] = entry
        tokens = ttws(line)
        for token in tokens:
            if token not in word2ind:
                word2ind[token] = idx
                idx = idx + 1

# %%
print(n_skipped, ' skipped')
print(len(sentences), ' kept')
# Out:
# 2775  skipped
# 9077  kept

# %%
data_splits = {title: {'x':[], 'y':[]} for title in ['train', 'test', 'val']}
for line, entry in sentences.items():
    which = entry['split_set']
    tokenized = [int(word2ind[token]) for token in ttws(line)]
    (data_splits[which]['x']).append(tokenized)
    (data_splits[which]['y']).append(int(entry['y']))

# %%
for title in ['train', 'test', 'val']:
    print(title + ' dataset size:', len(data_splits[title]['x']))
# Out:
# train dataset size: 6530
# test dataset size: 1702
# val dataset size: 845

# %%
def get_dataset(label, sequence_len):
    vals = data_splits[label]
    x = [np.array(vx) for vx in vals['x']]
    x = tf.keras.preprocessing.sequence.pad_sequences(x,
                                                      padding = 'post',
                                                      maxlen = sequence_len)
    y = np.array(vals['y'])
    return x, y

# %%
def get_embedding_matrix(glove_size):
    glove = get_glove(glove_size)
    glove_words = set(glove.keys())
    default_vector = np.mean(list(glove.values()), axis = 0)
    embedding_matrix = np.empty((len(word2ind), default_vector.shape[0]))
    for word, position in word2ind.items():
        embedding_matrix[position,:] = glove.get(word, default_vector)
    return embedding_matrix

# %% [markdown]
# ### 2.1 Define Network Models

# %%
class CNNModel(tf.keras.Model):
    
    def __init__(self, embedding = 300, embeddings = False):
        super(CNNModel, self).__init__()
        
        self.logistic = tf.keras.layers.Dense(1, activation = 'sigmoid')
        
    def call(self, inputs, training = False):
        x = self.embedding(inputs)
        mask = self.embedding.compute_mask(inputs)
        for layer in self.hidden_layers:
            layer(x, mask = mask)
            mask = None
        return self.logistic(self.final_rnn(x, mask = mask))
            
def compile_model(model = RnnModel, lr = .01, model_args = {}, metrics = ['BinaryAccuracy']):
    net = model(**model_args)
    optimizer = tf.keras.optimizers.Adam(learning_rate = lr)
    net.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = metrics)
    return net

def run_model(model_type = RnnModel, verbose = 2, epochs = 100, batch_size = 500, 
              sequence_len = 25, learning_rate = .001, model_args = {}):
    (xtrain, ytrain)= get_dataset('train', sequence_len)
    (xval, yval) = get_dataset('val', sequence_len)
    model = compile_model(model_type, learning_rate, model_args)
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                                   patience=2, 
                                                   restore_best_weights = True)
    train_history = model.fit(xtrain, ytrain, 
                              callbacks = [es_callback],
                              validation_data = (xval, yval),
                              batch_size = batch_size,
                              epochs = epochs,
                              verbose = verbose)
    return train_history

# %% [markdown]
# ### 2.2 Run a basic Rnn Model

# %%
vanilla_hists = [run_model()]
# Out:
# WARNING:tensorflow:From /home/evl/andrew/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/evl/andrew/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:3794: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 6530 samples, validate on 845 samples
# Epoch 1/100
# 6530/6530 - 1s - loss: 0.7056 - binary_accuracy: 0.5270 - val_loss: 0.6990 - val_binary_accuracy: 0.5302
# Epoch 2/100
# 6530/6530 - 0s - loss: 0.6794 - binary_accuracy: 0.5631 - val_loss: 0.6793 - val_binary_accuracy: 0.5680
# Epoch 3/100
# 6530/6530 - 0s - loss: 0.6641 - binary_accuracy: 0.5882 - val_loss: 0.6652 - val_binary_accuracy: 0.5976
# Epoch 4/100
# 6530/6530 - 0s - loss: 0.6509 - binary_accuracy: 0.6103 - val_loss: 0.6513 - val_binary_accuracy: 0.6189
# Epoch 5/100
# 6530/6530 - 0s - loss: 0.6386 - binary_accuracy: 0.6328 - val_loss: 0.6369 - val_binary_accuracy: 0.6379
# Epoch 6/100
# 6530/6530 - 0s - loss: 0.6249 - binary_accuracy: 0.6453 - val_loss: 0.6212 - val_binary_accuracy: 0.6663
# Epoch 7/100
# 6530/6530 - 0s - loss: 0.6089 - binary_accuracy: 0.6675 - val_loss: 0.6002 - val_binary_accuracy: 0.6864
# Epoch 8/100
# 6530/6530 - 0s - loss: 0.5903 - binary_accuracy: 0.6873 - val_loss: 0.5794 - val_binary_accuracy: 0.7243
# Epoch 9/100
# 6530/6530 - 0s - loss: 0.5704 - binary_accuracy: 0.7115 - val_loss: 0.5485 - val_binary_accuracy: 0.7503
# Epoch 10/100
# 6530/6530 - 0s - loss: 0.5478 - binary_accuracy: 0.7363 - val_loss: 0.5338 - val_binary_accuracy: 0.7562
# Epoch 11/100
# 6530/6530 - 0s - loss: 0.5289 - binary_accuracy: 0.7470 - val_loss: 0.5259 - val_binary_accuracy: 0.7562
# Epoch 12/100
# 6530/6530 - 0s - loss: 0.5162 - binary_accuracy: 0.7606 - val_loss: 0.5278 - val_binary_accuracy: 0.7491
# Epoch 13/100
# 6530/6530 - 0s - loss: 0.5124 - binary_accuracy: 0.7608 - val_loss: 0.5201 - val_binary_accuracy: 0.7586
# Epoch 14/100
# 6530/6530 - 0s - loss: 0.5008 - binary_accuracy: 0.7695 - val_loss: 0.5135 - val_binary_accuracy: 0.7609
# Epoch 15/100
# 6530/6530 - 0s - loss: 0.4967 - binary_accuracy: 0.7709 - val_loss: 0.5414 - val_binary_accuracy: 0.7408
# Epoch 16/100
# 6530/6530 - 0s - loss: 0.5184 - binary_accuracy: 0.7525 - val_loss: 0.5171 - val_binary_accuracy: 0.7680

# %% [markdown]
# ### 2.3 Run a basic LSTM Model

# %%
vanilla_lstm_hist = run_model(LstmModel)
vanilla_hists.append(vanilla_lstm_hist)
# Out:
# Train on 6530 samples, validate on 845 samples
# Epoch 1/100
# 6530/6530 - 1s - loss: 0.7036 - binary_accuracy: 0.5080 - val_loss: 0.6838 - val_binary_accuracy: 0.5680
# Epoch 2/100
# 6530/6530 - 0s - loss: 0.6717 - binary_accuracy: 0.5942 - val_loss: 0.6583 - val_binary_accuracy: 0.6296
# Epoch 3/100
# 6530/6530 - 0s - loss: 0.6492 - binary_accuracy: 0.6533 - val_loss: 0.6275 - val_binary_accuracy: 0.6793
# Epoch 4/100
# 6530/6530 - 0s - loss: 0.6151 - binary_accuracy: 0.6827 - val_loss: 0.5791 - val_binary_accuracy: 0.7231
# Epoch 5/100
# 6530/6530 - 0s - loss: 0.5727 - binary_accuracy: 0.7156 - val_loss: 0.5348 - val_binary_accuracy: 0.7456
# Epoch 6/100
# 6530/6530 - 0s - loss: 0.5407 - binary_accuracy: 0.7329 - val_loss: 0.5143 - val_binary_accuracy: 0.7586
# Epoch 7/100
# 6530/6530 - 0s - loss: 0.5183 - binary_accuracy: 0.7458 - val_loss: 0.5008 - val_binary_accuracy: 0.7680
# Epoch 8/100
# 6530/6530 - 0s - loss: 0.5001 - binary_accuracy: 0.7628 - val_loss: 0.4862 - val_binary_accuracy: 0.7728
# Epoch 9/100
# 6530/6530 - 0s - loss: 0.4876 - binary_accuracy: 0.7681 - val_loss: 0.4754 - val_binary_accuracy: 0.7799
# Epoch 10/100
# 6530/6530 - 0s - loss: 0.4760 - binary_accuracy: 0.7779 - val_loss: 0.4700 - val_binary_accuracy: 0.7822
# Epoch 11/100
# 6530/6530 - 0s - loss: 0.4710 - binary_accuracy: 0.7784 - val_loss: 0.4639 - val_binary_accuracy: 0.7822
# Epoch 12/100
# 6530/6530 - 0s - loss: 0.4602 - binary_accuracy: 0.7832 - val_loss: 0.4618 - val_binary_accuracy: 0.7811
# Epoch 13/100
# 6530/6530 - 0s - loss: 0.4494 - binary_accuracy: 0.7911 - val_loss: 0.4587 - val_binary_accuracy: 0.7846
# Epoch 14/100
# 6530/6530 - 0s - loss: 0.4466 - binary_accuracy: 0.7922 - val_loss: 0.4576 - val_binary_accuracy: 0.7893
# Epoch 15/100
# 6530/6530 - 0s - loss: 0.4386 - binary_accuracy: 0.8000 - val_loss: 0.4581 - val_binary_accuracy: 0.7893
# Epoch 16/100
# 6530/6530 - 0s - loss: 0.4328 - binary_accuracy: 0.8031 - val_loss: 0.4582 - val_binary_accuracy: 0.7929

# %% [markdown]
# ### 2.4 Run a basic Gru Model

# %%
vanilla_gru_hist = run_model(GruModel)
vanilla_hists.append(vanilla_gru_hist)
# Out:
# Train on 6530 samples, validate on 845 samples
# Epoch 1/100
# 6530/6530 - 1s - loss: 0.6903 - binary_accuracy: 0.5381 - val_loss: 0.6737 - val_binary_accuracy: 0.5763
# Epoch 2/100
# 6530/6530 - 0s - loss: 0.6632 - binary_accuracy: 0.6003 - val_loss: 0.6531 - val_binary_accuracy: 0.6154
# Epoch 3/100
# 6530/6530 - 0s - loss: 0.6454 - binary_accuracy: 0.6315 - val_loss: 0.6371 - val_binary_accuracy: 0.6320
# Epoch 4/100
# 6530/6530 - 0s - loss: 0.6309 - binary_accuracy: 0.6453 - val_loss: 0.6220 - val_binary_accuracy: 0.6485
# Epoch 5/100
# 6530/6530 - 0s - loss: 0.6156 - binary_accuracy: 0.6642 - val_loss: 0.6052 - val_binary_accuracy: 0.6793
# Epoch 6/100
# 6530/6530 - 0s - loss: 0.5987 - binary_accuracy: 0.6882 - val_loss: 0.5844 - val_binary_accuracy: 0.7124
# Epoch 7/100
# 6530/6530 - 0s - loss: 0.5776 - binary_accuracy: 0.7072 - val_loss: 0.5593 - val_binary_accuracy: 0.7219
# Epoch 8/100
# 6530/6530 - 0s - loss: 0.5513 - binary_accuracy: 0.7297 - val_loss: 0.5313 - val_binary_accuracy: 0.7420
# Epoch 9/100
# 6530/6530 - 0s - loss: 0.5230 - binary_accuracy: 0.7479 - val_loss: 0.5038 - val_binary_accuracy: 0.7574
# Epoch 10/100
# 6530/6530 - 0s - loss: 0.4962 - binary_accuracy: 0.7629 - val_loss: 0.4811 - val_binary_accuracy: 0.7704
# Epoch 11/100
# 6530/6530 - 0s - loss: 0.4768 - binary_accuracy: 0.7767 - val_loss: 0.4770 - val_binary_accuracy: 0.7834
# Epoch 12/100
# 6530/6530 - 0s - loss: 0.4642 - binary_accuracy: 0.7870 - val_loss: 0.4695 - val_binary_accuracy: 0.7728
# Epoch 13/100
# 6530/6530 - 0s - loss: 0.4567 - binary_accuracy: 0.7904 - val_loss: 0.4709 - val_binary_accuracy: 0.7751
# Epoch 14/100
# 6530/6530 - 0s - loss: 0.4526 - binary_accuracy: 0.7917 - val_loss: 0.4711 - val_binary_accuracy: 0.7775

# %% [markdown]
# ### 2.5 Plot Accuracy and Loss for the 3 basic models

# %%
def plot_history(histories, title = None, sub_titles = None, width = 2, plot_metrics = None):
    if plot_metrics is not None:
        plot_metrics += ['val_' + m for m in plot_metrics]
    else:
        plot_metrics = list(histories[0].history.keys())
    histories = [h.history for h in histories]
    n_plots = len(histories)
    options = {'figsize': [20,30]}
    fig, ax = plt.subplots(n_plots, **options)
    if title is not None:
        fig.suptitle(title)
    for i in range(n_plots):
        history = histories[i]
        for key in plot_metrics:
            vals = history[key]
            ax[i].plot(range(len(vals)), vals, label=key)
            if sub_titles is not None:
                ax[i].set_title(sub_titles[i])
        if len(history.keys()) > 1:
            ax[i].legend()
plot_history(vanilla_hists,
             title = 'Training and Validation loss for 1 layer RNN variants', 
             sub_titles = ['Rnn','LSTM','GRU'])

# %%
#report the number of itterations that got the best validation accuracy
def best_timestep(history, metric_name = 'val_binary_accuracy', big_good = True):
    values = history.history[metric_name]
    evals = [np.mean( values[np.max([i-1,0]): np.min([i+1,len(values)-1])] ) for i in range(len(values))]
    if not big_good:
        evals = [-i for i in evals]
    best_itter = np.argmax(evals)
    best_val = values[best_itter]
    result = {key: value[best_itter] for key, value in history.history.items() if re.search('val_', key) is not None}
    result['itter'] = best_itter
    return result
[best_timestep(hist) for hist in vanilla_hists]
# Out:
# [{'val_loss': 0.5134511198517839,
#   'val_binary_accuracy': 0.76094675,
#   'itter': 13},
#  {'val_loss': 0.458090587833224,
#   'val_binary_accuracy': 0.78934914,
#   'itter': 14},
#  {'val_loss': 0.4694531284845792,
#   'val_binary_accuracy': 0.7727811,
#   'itter': 11}]

# %% [markdown]
# ### 2.6 Experiment with Model Parameters
# This section includes result plots from training an LSTM (as it has the best vanilla performance) vs variations of a single parameter one-at-a-time, so that we can keep the plots a reasonable number

# %%
#I don't want to run a million experiments so I'll stick to the GRU model
best_model = LstmModel
best_epochs = 20
run_args = {'model_type': best_model,
           'epochs': best_epochs,
           'verbose': 0}

# %%
def get_best_results(history_list, configs):
    best_result_list = [best_timestep(hist) for hist in history_list]
    best_config = configs[ np.argmax([n['val_binary_accuracy'] for n in best_result_list]) ]
    print([n['val_binary_accuracy'] for n in best_result_list])
    return best_config

def lineplot_small_multiples(histories, title = None, sub_title_func = None, width = 2):
    histories = [h.history for h in histories]
    n_plots = len(histories)
    n_rows = int(np.ceil(n_plots/width))
    options = {'figsize': [40/n_rows,30/width]}
    fig, ax = plt.subplots(n_rows, width, **options)
    if title is not None:
        fig.suptitle(title)
    for i in range(n_rows*width):
        x = int(i%width)
        y = int(np.floor(i/width))
        if n_rows > 1 and width > 1:
            axis = ax[y,x]
        elif width > 1:
            axis = ax[x]
        else:
            axis = ax[y]
        if i < n_plots:
            history = histories[i]
            for key, vals in history.items():
                axis.plot(range(len(vals)), vals, label=key)
                if sub_title_func is not None:
                    axis.set_title(sub_title_func(i))
            if len(history.keys()) > 1:
                axis.legend()
        else:
            fig.delaxes(axis)

# %% [markdown]
# #### 2.6.1 Testing Out Sequence Lengths

# %%
seq_len_hists = []
seq_options = [12, 25, 36, 50]
for seq_len in seq_options:
    history = run_model(**run_args)
    seq_len_hists.append(history)
best_seq_len = get_best_results(seq_len_hists, seq_options)
run_args['sequence_len'] = best_seq_len
# Out:
# [0.7846154, 0.7905325, 0.7857988, 0.7857988]

# %%
lineplot_small_multiples(seq_len_hists, title = 'Sequence Length Training Behavior', sub_title_func = lambda x: str(seq_options[x]))

# %% [markdown]
# ##### 2.6.1-Discussion
# The sequence lengths dont seem to have a strong impact on the accuracy of the results.  However, it seems that 50 (the max sentence length is ~49) is the best for this instance, although 12 does a good job, potentiall due to avoiding overfitting.

# %% [markdown]
# #### 2.6.2 Testing Out Hidden Layer Sizes

# %%
layer_hists = []
layer_configs = [[4], [8], [16], [32]]
for layer_config in layer_configs:
    model_args = {'hidden_states': layer_config}
    history = run_model(model_args = model_args, **run_args)
    layer_hists.append(history)
best_layer_config = get_best_results(layer_hists, layer_configs)
model_args = {'hidden_states': best_layer_config}
# Out:
# [0.76804733, 0.7775148, 0.77633137, 0.78934914]

# %%
lineplot_small_multiples(layer_hists, title = 'Layer Size Training Behavior', 
                         sub_title_func = lambda x: str(layer_configs[x]))

# %% [markdown]
# #### 2.6.2 - Discussion
# Small layer sizes tend to do slightly better, with 4 cells getting the highest validation accuracy (79.5).  This seems to be an overfitting problem, as the training for 4 and 8 layers also goes on longer before early stopping is activated (~17 itterations vs 8 for 32 hidden units)

# %% [markdown]
# #### 2.6.3 Testing Glove Size Embeddings

# %%
glove_layer_sizes = [50, 100, 300]
glove_hists = []
for glove_size in glove_layer_sizes:
    model_args['embedding'] = glove_size
    history = run_model(model_args = model_args, **run_args)
    glove_hists.append(history)
best_glove_size = get_best_results(glove_hists, glove_layer_sizes)
model_args['embedding'] = best_glove_size
# Out:
# [0.747929, 0.7751479, 0.7857988]

# %%
lineplot_small_multiples(glove_hists, title = 'Glove Embedding Size Training Behavior',
                        sub_title_func = lambda x: str(glove_layer_sizes[x]))

# %% [markdown]
# #### 2.6.3 - Discussion
# Larger embedding sizes seem to perform best, with 300 layers far outperforming 50 and 100 dimensions.  Lower dimensional embedding also improved more slowly, but all required ~17 itterations before early stopping, suggesting that overfitting isn't an issue as much.

# %% [markdown]
# #### 2.6.4 Fine-Tuning Embedding Vs Not

# %%
train_glove_configs = [True, False]
train_glove_hist = []
for train_glove in train_glove_configs:
    model_args['train_embeddings'] = train_glove
    history = run_model(model_args = model_args, **run_args)
    train_glove_hist.append(history)
should_we_train_glove = get_best_results(train_glove_hist, train_glove_configs)
model_args['train_embeddings'] = should_we_train_glove
# Out:
# [0.77988166, 0.7786982]

# %%
lineplot_small_multiples(train_glove_hist, width = 1,
                         title = 'Effect of Fine Tunning on Performance',
                         sub_title_func = lambda x: 'Fine Tunning' if x == 0 else 'No Fine Tunning')

# %% [markdown]
# #### 2.6.4 - Discussion
# Fine Tunning embedding seems to perform worse.  Overfitting is a large issue, as the validation training loss goes down much faster, but validation accuracy goes down over 2-3 epochs with Fine tunning.

# %% [markdown]
# #### 2.6.5 What are the final arguments that we found performed the best
# I will note that because of randomization, some parameters may vary (e.g. sequence length, as it is inconsistent when run many times)

# %%
for k, v in model_args.items():
    print(k + ':', v)
print('sequence length:', run_args['sequence_len'])
# Out:
# hidden_states: [32]
# embedding: 300
# train_embeddings: True
# sequence length: 25

# %% [markdown]
# ### 3.1 Find the best model (using validation accuracy)
# Since the above only explored a few options, were are going to try out different parameters to get the best ones for each model type.
# Since sequences length has not important, it is being set to 50.  Epochs are set to a high 40 as we're using early stopping to decide when to stop training.
#
# Values tested are:
#     * Embedding Size (50, 100, 300)
#     * Number of Hidden States (4,8,16)
#     * Whether to fine-tune embeddings or not
#
# This code chunk finds the best variant for each RNN/LSTM/GRU and reports the test precision/recall/f1 score for each best model

# %%
def find_best_model(model_type, seq_len = 50, epochs = 40):
    xtrain, ytrain = get_dataset('train', seq_len)
    xval, yval = get_dataset('val', seq_len)
    best_score = 0
    best_model = None
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                patience=2, 
                                restore_best_weights = True)
    for embedding in [50,100,300]:
        for hidden_states in [[4], [8], [16]]:    
            for train_embeddings in [True, False]:
                model_args = {'hidden_states': hidden_states,
                             'embedding': embedding,
                             'train_embeddings': train_embeddings}
                model = compile_model(model_type, .005, model_args, 
                                      ['BinaryAccuracy','Precision','Recall'])
                hist = model.fit(xtrain, ytrain,
                          validation_data = (xval, yval),
                          callbacks = [es_callback],
                          batch_size = 500,
                          epochs = epochs,
                          verbose = 0)
                score = np.max(hist.history['val_binary_accuracy'])
                if score > best_score:
                    best_score = score
                    best_model = model
                    print(score)
    return model

def evaluate_best_model(model_type):
    model = find_best_model(model_type)
    xtest, ytest = get_dataset('test', 50)
    [eval_loss, eval_acc, eval_precision, eval_recall] = model.evaluate(xtest, ytest)
    f1_score = 2*eval_precision*eval_recall/(eval_precision + eval_recall)
    result = {'precision': eval_precision, 'recall': eval_recall, 'f1_score': f1_score}
    return model.__class__.__name__, result

# %%
result_dict = {}
for m in [RnnModel, LstmModel, GruModel]:
    model_name, res = evaluate_best_model(m)
    result_dict[model_name] = res
# Out:
# 0.7337278
# 0.7621302
# 0.7704142
# 0.7786982
# 0.7810651
# 1702/1702 [==============================] - 0s 106us/sample - loss: 0.5477 - binary_accuracy: 0.7350 - precision_34: 0.7616 - recall_34: 0.6993
# 0.8071006
# 0.8130177
# 1702/1702 [==============================] - 0s 231us/sample - loss: 0.4713 - binary_accuracy: 0.7650 - precision_70: 0.7612 - recall_70: 0.7857
# 0.7112426
# 0.79881656
# 1702/1702 [==============================] - 0s 280us/sample - loss: 0.4616 - binary_accuracy: 0.7744 - precision_106: 0.7750 - recall_106: 0.7857

# %% [markdown]
# #### 3.2  Reporting The results
# LSTM and GRU both do much better than an RNN, mostly due to better recall.  Overall GRU did slightly better than LSTM for this run, but not enough to make a significant difference.
#
# All models do much better on their validation set than the test set, with the RNN, LSTM, and GRU getting (for the run I am writting this for) 78.1%, 81.3%, and 79.9% on the validation accuracy, but 73.5%, 76.5%, and 77.3% on the test set, respectively, which suggest some noise in the effect that the various meta-parameters had on the model.

# %%
result_df = pd.DataFrame(result_dict).T
result_df
# Out:
#            f1_score  precision    recall
# RnnModel   0.729129   0.761606  0.699309
# LstmModel  0.773243   0.761161  0.785714
# GruModel   0.780320   0.775000  0.785714

# %%
result_df.T.plot(kind='barh')
